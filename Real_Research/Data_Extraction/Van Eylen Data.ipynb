# %%
#Hour and six minutes

import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import scipy
from scipy.stats import rayleigh
fig, ax = plt.subplots(1, 1)

# %matplotlib inline


original_e_list = [0.06, 0.05, 0.06, 0.02, 0.08, 0.05, 0.01, 
                  0.08, 0.05, 0.01, 0.08, 0.09, 0.15, 0.02, 0.08, 0.10,
                  0.02, 0.42, 0.17, 0.04, 0.07, 0.13, 0.02, 0.38, 0.03, 
                  0.02, 0.38, 0.03, 0.02, 0.02, 0.02, 0.14, 0.02, 0.22, 
                  0.04, 0.21, 0.03, 0.07, 0.19, 0.02, 0.47, 0.03, 0.03, 
                  0.01, 0.20, 0.15, 0.08, 0.80, 0.43, 0.11, 0.02, 0.08,
                  0.03, 0.38, 0.04, 0.51, 0.04, 0.03, 0.03, 0.05, 0.08, 
                  0.12, 0.18, 0.02, 0.58, 0.03, 0.05, 0.02, 0.02, 0.14, 
                  0.09, 0.10]


rayleigh_args = stats.rayleigh.fit(original_e_list)
print(rayleigh_args)
print(np.average(original_e_list))








mean, var, skew, kurt = rayleigh.stats(moments='mvsk')



x = np.linspace(rayleigh.ppf(0.01),
                rayleigh.ppf(0.99), 100)
ax.plot(x, rayleigh.pdf(x),
       'r-', lw=5, alpha=0.6, label='rayleigh pdf')
rv = rayleigh()
ax.plot(x, rv.pdf(x), 'k-', lw=2, label='frozen pdf')
vals = rayleigh.ppf([0.001, 0.5, 0.999])
np.allclose([0.001, 0.5, 0.999], rayleigh.cdf(vals))




r = rayleigh.rvs(size=1000)

ax.hist(r, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()


print("All before this")

















star_m_list = [0.92, 0.92, 1.078, 1.078, 1.078, 1.078,
               1.16, 1.16, 0.81, 0.81, 0.81, 1.199, 1.199, 1.199, 
               1.07, 1.07, 1.209, 1.209, 1.209, 1.109, 1.109, 1.109, 
               1.099, 1.099, 1.142, 1.142, 1.142, 1.142, 1.377, 1.377,
               1.069, 1.069, 1.148, 1.148, 1.148, 1.240, 1.240, 1.240,
               1.159, 1.159, 0.934, 0.934, 0.934, 1.419, 1.419, 0.922, 
               0.922, 0.922, 0.922, 1.298, 1.298, 
               1.142, 1.142, 1.142, 1.142, 0.74, 0.74, 0.74, 0.74, 0.74, 
               0.969, 0.969, 1.346, 1.346, 1.346, 1.199, 1.199]


#print("m" + str(np.mean(star_m_list)))


k10 = [0.83749026, 45.294292, 0.06, 0.05]
k23_1 = [7.106995, 10.742434, 0.06, 0.02]
k23_2 = [10.742434, 15.27429, 0.02, 0.08]
k25 = [6.2385369, 12.7203678, 0.05, 0.01]
k37_1 = [13.368, 21.3021, 0.08, 0.09]
k37_2 = [21.3021, 39.792232, 0.09, 0.15]
k65_1 = [2.1549156, 5.8599408, 0.02, 0.08]
k65_2 = [5.8599408, 8.131231, 0.08, 0.10]
k68 = [5.3987533, 9.604979, 0.02, 0.42]
k92_1 = [13.748933, 26.72311, 0.17, 0.04]
k92_2 = [26.72311, 49.3468, 0.04, 0.07]
k100_1 = [6.887037, 12.815909, 0.13, 0.02]
k100_2 = [12.815909, 35.33313, 0.02, 0.38]
k103 = [15.965316, 179.6133, 0.03, 0.02]
k107_1 = [3.18, 4.901441, 0.02, 0.02]
k107_2 = [4.901441, 7.95825, 0.02, 0.14]
k107_3 = [7.95825, 14.749176, 0.14, 0.02]
k108 = [49.18354, 190.3214, 0.22, 0.04]
k109 = [6.4816370, 21.222620, 0.21, 0.03]
k126_1 = [10.495634, 21.86964, 0.07, 0.19]
k126_2 = [21.86964, 100.28208, 0.19, 0.02]
k127_1 = [14.43577, 29.39344, 0.47, 0.03]
k127_2 =  [29.39344, 48.62997, 0.03, 0.03]
k129 = [15.791619, 82.1908, 0.01, 0.2]
k130_1 = [8.45725, 27.508686, 0.15, 0.08]
k130_2 = [27.508686, 87.5211, 0.08, 0.8]
k145 = [22.95102, 42.88254, 0.43, 0.11]
k197_1 = [5.599293, 10.349711, 0.02, 0.08]
k197_2 = [10.349711, 15.67787, 0.08, 0.03]
k197_3 = [15.67787, 25.2097, 0.03, 0.38] 
k278 = [30.15856, 51.0851, 0.04, 0.51]
k338_1 = [9.34149, 13.72699, 0.05, 0.04] #This is the problem child
k338_2 = [13.72699, 24.31168, 0.04, 0.03]
k338_3 =  [24.31168, 44.4287, 0.03, 0.03]
k444_1 = [3.6, 4.545817, 0.08, 0.12]
k444_2 = [4.545817, 6.189512, 0.12, 0.18]
k444_3 = [6.189512, 7.74350, 0.18, 0.02]
k444_4 = [7.74350,9.740529, 0.02, 0.58]
k449 = [12.58242, 33.6727, 0.03, 0.05]
k450_1 = [4.780327, 7.05174, 0.09, 0.10] #Another problem child
k450_2 = [7.05174, 7.51464, 0.10, 0.14]
k450_3 = [7.51464, 15.413135, 0.14, 0.02  ]
k450_4 = [15.413135,28.454851, 0.02, 0.02 ]
          
big_p_list =[  k10, k23_1, k23_2, k25, k37_1, k37_2, k65_1, k65_2, k68, k92_1, k92_2, k100_1, k100_2,
            k103, k107_1, k107_2, k108, k109, k126_1, k126_2, k127_1, k127_2, k129, 
            k130_1, k130_2, k145, k197_1, k197_2, k197_3, k278, k338_1, k338_2, k338_3, 
            k444_1, k444_2, k444_3, k444_4, k449, k450_1, k450_2, k450_3, k450_4]

three_or_more_p_list = [  k23_1, k23_2, k37_1, k37_2, k65_1, k65_2, k92_1, k92_2, k100_1, k100_2,
            k107_1, k107_2, k126_1, k126_2, k127_1, k127_2,
            k130_1, k130_2, k197_1, k197_2, k197_3, k338_1, k338_2, k338_3, 
            k444_1, k444_2, k444_3, k444_4, k450_1, k450_2, k450_3, k450_4]


filtered_three_or_more_p_list = []
for i in three_or_more_p_list:
    if ( (i[1]/i[0]) > 1.1 and (i[1]/i[0]) < 1.5 ):
        filtered_three_or_more_p_list.append(i)

        
        
        
        
        
three_or_more_e_list = []
for i in filtered_three_or_more_p_list:
    three_or_more_e_list.append(i[2])
    three_or_more_e_list.append(i[3])

   

print("filtered three or more e: " + str(np.average(three_or_more_e_list)))
        
        






    
plt.hist(three_or_more_e_list, bins=np.linspace(0.0,0.7, 20),
                   histtype=u'step', density = False)

plt.show()




complete_p_list = []
for i in big_p_list:
    complete_p_list.append(i[0])
complete_p_list.append(k10[1])
complete_p_list.append(k25[1])
complete_p_list.append(k68[1])
complete_p_list.append(k103[1])
complete_p_list.append(k108[1])
complete_p_list.append(k109[1])
complete_p_list.append(k129[1])
complete_p_list.append(k145[1])
complete_p_list.append(k278[1])
complete_p_list.append(k449[1])

plt.hist(complete_p_list)


plt.show()



pratio_list = []
for i in big_p_list:
    pratio_list.append(i[1]/i[0])

pratio_15_list = []
for i in range(len(pratio_list)):
    original_e_list.append(big_p_list[i][2])
    original_e_list.append(big_p_list[i][3])
    if pratio_list[i] > 1.5:
        pratio_15_list.append(pratio_list[i])
        filtered_e_list.append(big_p_list[i][2])
        filtered_e_list.append(big_p_list[i][3])
# Out:
# (-0.09377054685829661, 0.1862573707272342)
# 0.12013888888888889
# All before this
# filtered three or more e: 0.11625

# %%
print("Original mean" + str(np.mean(original_e_list)))
print(max(original_e_list))
print("New Mean" + str(np.mean(filtered_e_list)))
print("difference" + str(np.mean(original_e_list) - np.mean(filtered_e_list)))
# Out:
# Original mean0.11564102564102563
# 0.8
# New Mean0.11045454545454544
# difference0.005186480186480186

# %%
num_iter = 10000
e_mean = 0.049
e_error = 0.013

test_e_list = []

for i in range(num_iter):
    #Generate e using Rayleigh Distribution
    #e_mu = np.random.normal(e_mean)
    e = np.random.rayleigh(scale = e_mean)
    test_e_list.append(e)
    #Generate a_ratio


    
#test_e_cum_norm = np.cumsum(test_e_list)/max(np.cumsum(test_e_list))
#observed_e_cum_norm = np.cumsum(original_e_list)/max(np.cumsum(original_e_list))

bins = bins=np.linspace(0, 0.8, 20)

test_count, test_edges = np.histogram(test_e_list, bins=bins)
test_pdf = test_count/sum(test_count)
test_norm_cumulative = np.cumsum(test_pdf)

obs_count, obs_edges = np.histogram(original_e_list, bins=bins)
obs_pdf = obs_count/sum(obs_count)
obs_norm_cumulative = np.cumsum(obs_pdf)


ksprob = scipy.stats.kstest(obs_norm_cumulative, test_norm_cumulative, args = (), alternative = 'two-sided',
                                method = 'exact')

pvalue = ksprob[1]
print(pvalue)


plt.plot(test_edges[1:], test_norm_cumulative)
plt.plot(test_edges[1:], obs_norm_cumulative)
plt.title("Observed and Van Eylen Eccentricity cdfs")
plt.show()


"""
count, edges = np.histogram(pairs['Pratio'][mask], bins=bins)

values = count

pdf = count/sum(count)
observed_norm_cumulative = np.cumsum(pdf)

observed_period_pdf = count
observed_period_cdf = observed_norm_cumulative


"""

density = stats.gaussian_kde(original_e_list)
n, x, _ = plt.hist(original_e_list, bins=bins,
                   histtype=u'step', density=True)  
plt.plot(x, density(x))
plt.title("Eccentricity Distributions")
plt.xlabel("Eccentricity")
plt.ylabel("Density")
density = stats.gaussian_kde(test_e_list)
n, x, _ = plt.hist(test_e_list, bins=bins,
                   histtype=u'step', density=True)  
plt.plot(x, density(x))




plt.show()
# Out:
# 4.176797231882591e-06

# %%
rayleigh_args_og = stats.rayleigh.fit(original_e_list)

rayleigh_args_og = stats.rayleigh.fit(three_or_more_e_list)

print(three_or_more_e_list[1] - original_e_list[1])
# Out:
# 0.03

# %%
from scipy.stats import rayleigh
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots(1, 1)



mean, var, skew, kurt = rayleigh.stats(moments='mvsk')


rayleigh_args = stats.rayleigh.fit(original_e_list)
print(rayleigh_args)
print(np.average(original_e_list))


scale = rayleigh_args[1]


error = 0.013
simlist = []
for i in range(1000):
    scale = -1
    while ( ( scale < 0) or (scale > 1)):
        scale = np.random.normal(0.049, 0.1)
    
    simlist.append(np.random.rayleigh(scale = scale ))


density = stats.gaussian_kde(simlist)
n, x, _ = plt.hist(simlist, bins=np.linspace(0, 1, 75),
                   histtype=u'step', density=True)  
ax.plot(x, density(x), label = 'Simulated Eccentricity')
    
    
    
    
    
    
    

x = np.linspace(rayleigh.ppf(0.01),
                rayleigh.ppf(0.99), 100)







#ax.plot(x, rayleigh.pdf(x), 'r-', lw=5, alpha=0.6, label='rayleigh pdf')



rv = rayleigh()



#ax.plot(x, rv.pdf(x), 'k-', lw=2, label='frozen pdf')







density = stats.gaussian_kde(original_e_list)
n, x, _ = plt.hist(original_e_list, bins=np.linspace(0, 1, 75),
                   histtype=u'step', density=True)  


plt.title("Van Eylen Raw Eccentricity Data and Their Proposed Eccentricity Model")
plt.xlabel("Eccentricity")
plt.ylabel("Count")
ax.plot(x, density(x), label = 'Observed Eccentricity')





vals = rayleigh.ppf([0.001, 0.5, 0.999])
np.allclose([0.001, 0.5, 0.999], rayleigh.cdf(vals))



r = original_e_list



ax.hist(r, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# (-0.08808868380214409, 0.17778858664591687)
# 0.11564102564102563

# %%
from scipy.stats import rayleigh
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots(1, 1)



mean, var, skew, kurt = rayleigh.stats(moments='mvsk')


rayleigh_args = stats.rayleigh.fit(three_or_more_e_list)
print(rayleigh_args)
print(np.average(original_e_list))


scale = rayleigh_args[1]


error = 0.013
simlist = []
for i in range(1000):
    scale = -1
    while ( ( scale < 0) or (scale > 1)):
        scale = np.random.normal(0.09, 0.1)
    
    simlist.append(np.random.rayleigh(scale = scale ))


density = stats.gaussian_kde(simlist)
n, x, _ = plt.hist(simlist, bins=np.linspace(0, 1, 75),
                   histtype=u'step', density=True)  
ax.plot(x, density(x), label = 'Simulated Eccentricity')
    
    
    
    
    
    
    

x = np.linspace(rayleigh.ppf(0.01),
                rayleigh.ppf(0.99), 100)







#ax.plot(x, rayleigh.pdf(x), 'r-', lw=5, alpha=0.6, label='rayleigh pdf')



rv = rayleigh()



#ax.plot(x, rv.pdf(x), 'k-', lw=2, label='frozen pdf')







density = stats.gaussian_kde(three_or_more_e_list)
n, x, _ = plt.hist(three_or_more_e_list, bins=np.linspace(0, 1, 75),
                   histtype=u'step', density=True)  


plt.title("Van Eylen Raw Eccentricity Data, Pratio > 3/2, and Their Proposed Eccentricity Model")
plt.xlabel("Eccentricity")
plt.ylabel("Count")
ax.plot(x, density(x), label = 'Observed Eccentricity for Pratio > 3/2')





vals = rayleigh.ppf([0.001, 0.5, 0.999])
np.allclose([0.001, 0.5, 0.999], rayleigh.cdf(vals))



r = original_e_list



ax.hist(r, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# (-0.05998187550700969, 0.15444434506435994)
# 0.11564102564102563

# %%
from scipy.stats import rayleigh
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots(1, 1)



mean, var, skew, kurt = rayleigh.stats(moments='mvsk')


rayleigh_args = stats.rayleigh.fit(three_or_more_e_list)
print(rayleigh_args)
print(np.average(original_e_list))


scale = rayleigh_args[1]


error = 0.013
simlist = []
for i in range(1000):
    scale = -1
    while ( ( scale < 0) or (scale > 1)):
        scale = np.random.normal(0.049, 0.013)
    
    simlist.append(np.random.rayleigh(scale = scale ))


density = stats.gaussian_kde(original_e_list)
n, x, _ = plt.hist(original_e_list, bins=np.linspace(0, 1, 75),
                   histtype=u'step', density=True)  
ax.plot(x, density(x), label = 'Observed Eccentricity')
    
    
    
    
    
    
    

x = np.linspace(rayleigh.ppf(0.01),
                rayleigh.ppf(0.99), 100)







#ax.plot(x, rayleigh.pdf(x), 'r-', lw=5, alpha=0.6, label='rayleigh pdf')



rv = rayleigh()



#ax.plot(x, rv.pdf(x), 'k-', lw=2, label='frozen pdf')







density = stats.gaussian_kde(three_or_more_e_list)
n, x, _ = plt.hist(three_or_more_e_list, bins=np.linspace(0, 1, 75),
                   histtype=u'step', density=True)  


plt.title("Observed Eccentricities for All Planet Systems \n and for 3+ Planet Systems with P-Ratio > 3/2")
plt.xlabel("Eccentricity")
plt.ylabel("Count")
ax.plot(x, density(x), label = 'Observed Eccentricity for Pratio>3/2')





vals = rayleigh.ppf([0.001, 0.5, 0.999])
np.allclose([0.001, 0.5, 0.999], rayleigh.cdf(vals))



r = original_e_list



ax.hist(r, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# (-0.05998187550700969, 0.15444434506435994)
# 0.11564102564102563

# %%
from scipy.stats import rayleigh
import matplotlib.pyplot as plt



#original_e_list



mean, var, skew, kurt = rayleigh.stats(moments='mvsk')



fig, ax = plt.subplots(1, 1)

x = np.linspace(rayleigh.ppf(0.01),
                rayleigh.ppf(0.99), 100)

ax.plot(x, rayleigh.pdf(x),
       'r-', lw=5, alpha=0.6, label='rayleigh pdf')



rv = rayleigh()
ax.plot(x, rv.pdf(x), 'k-', lw=2, label='frozen pdf')


vals = rayleigh.ppf([0.001, 0.5, 0.999])
np.allclose([0.001, 0.5, 0.999], rayleigh.cdf(vals))



r = rayleigh.rvs(size=1000)



ax.hist(r, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# [0.06, 0.05, 0.06, 0.02, 0.08, 0.05, 0.01, 0.08, 0.05, 0.01, 0.08, 0.09, 0.15, 0.02, 0.08, 0.1, 0.02, 0.42, 0.17, 0.04, 0.07, 0.13, 0.02, 0.38, 0.03, 0.02, 0.38, 0.03, 0.02, 0.02, 0.02, 0.14, 0.02, 0.22, 0.04, 0.21, 0.03, 0.07, 0.19, 0.02, 0.47, 0.03, 0.03, 0.01, 0.2, 0.15, 0.08, 0.8, 0.43, 0.11, 0.02, 0.08, 0.03, 0.38, 0.04, 0.51, 0.04, 0.03, 0.03, 0.05, 0.08, 0.12, 0.18, 0.02, 0.58, 0.03, 0.05, 0.02, 0.02, 0.14, 0.09, 0.1, 0.06, 0.05, 0.06, 0.02, 0.02, 0.08, 0.05, 0.01, 0.08, 0.09, 0.09, 0.15, 0.02, 0.08, 0.08, 0.1, 0.02, 0.42, 0.17, 0.04, 0.04, 0.07, 0.13, 0.02, 0.02, 0.38, 0.03, 0.02, 0.02, 0.02, 0.02, 0.14, 0.22, 0.04, 0.21, 0.03, 0.07, 0.19, 0.19, 0.02, 0.47, 0.03, 0.03, 0.03, 0.01, 0.2, 0.15, 0.08, 0.08, 0.8, 0.43, 0.11, 0.02, 0.08, 0.08, 0.03, 0.03, 0.38, 0.04, 0.51, 0.05, 0.04, 0.04, 0.03, 0.03, 0.03, 0.08, 0.12, 0.12, 0.18, 0.18, 0.02, 0.02, 0.58, 0.03, 0.05, 0.09, 0.1, 0.1, 0.14, 0.14, 0.02, 0.02, 0.02]
